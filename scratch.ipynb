# %%
NOTION_API_KEY='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'
NOTION_PAGE_ID='190594e55a2880eaa1b1d7c51c96e90f'
database_id='190594e55a2881549acee31f5b04cc28'

# %%
from notion_client import Client
import pandas as pd

notion = Client(auth=NOTION_API_KEY)
notion.databases.query(database_id=database_id)
# Out:
# {'object': 'list',
#  'results': [{'object': 'page',
#    'id': '225594e5-5a28-80b2-9eee-feccde8863db',
#    'created_time': '2025-07-03T05:00:00.000Z',
#    'last_edited_time': '2025-07-06T02:45:00.000Z',
#    'created_by': {'object': 'user',
#     'id': 'abad9530-648f-4eb8-8597-24f62df8f3f6'},
#    'last_edited_by': {'object': 'user',
#     'id': 'abad9530-648f-4eb8-8597-24f62df8f3f6'},
#    'cover': None,
#    'icon': None,
#    'parent': {'type': 'database_id',
#     'database_id': '190594e5-5a28-8154-9ace-e31f5b04cc28'},
#    'archived': False,
#    'in_trash': False,
#    'properties': {'Position': {'id': '%24(WG',
#      'type': 'rich_text',
#      'rich_text': [{'type': 'text',
#        'text': {'content': '2026 | Americas | New York City Area | Engineering | New Analyst',
#         'link': {'url': 'https://hdpc.fa.us2.oraclecloud.com/hcmUI/CandidateExperience/en/sites/CampusHiring/job/150845'}},
#        'annotations': {'bold': False,
#         'italic': False,
# ...
